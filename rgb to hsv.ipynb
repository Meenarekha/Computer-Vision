# %%
import cv2
import matplotlib.pyplot as plt
image1=cv2.imread(r"C:\Users\student\Pictures\cv\butterfly.jfif")
hsv_image=cv2.cvtColor(image1,cv2.COLOR_BGR2HSV)

h_channel, s_channel, v_channel = cv2.split(hsv_image)

plt.figure(figsize=(15, 5))

plt.subplot(1,4,1)
plt.title('HSV Image')
plt.imshow(hsv_image)
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(h_channel)
plt.title('Hue Channel')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(s_channel)
plt.title('Saturation Channel')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(v_channel)
plt.title('Value Channel')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
image2=cv2.imread(r"C:\Users\student\Pictures\cv\pic 2.png")
hsv_image1=cv2.cvtColor(image2,cv2.COLOR_BGR2HSV)

h_channel1, s_channel1, v_channel1 = cv2.split(hsv_image1)

plt.figure(figsize=(15, 5))

plt.subplot(1,4,1)
plt.title('HSV Image')
plt.imshow(hsv_image1)
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(h_channel1)
plt.title('Hue Channel')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(s_channel1)
plt.title('Saturation Channel')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(v_channel1)
plt.title('Value Channel')
plt.axis('off')

plt.show()
